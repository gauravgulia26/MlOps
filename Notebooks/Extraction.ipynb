# %%
data = {
    "metadata": {"page": 0, "per_page": 20, "total": 10},
    "results": [
        {
            "id": 104151,
            "latest.admissions.admission_rate.overall": 0.8975,
            "latest.completion.rate_suppressed.consumer.median_by_pred_degree": 0.5817,
            "latest.completion.rate_suppressed.consumer.overall_median": 0.5857,
            "latest.completion.rate_suppressed.four_year": 0.6646,
            "latest.completion.rate_suppressed.four_year_100_pooled": 0.5259,
            "latest.completion.rate_suppressed.four_year_200percent": 0.6788,
            "latest.completion.rate_suppressed.lt_four_year": "null",
            "latest.completion.rate_suppressed.lt_four_year_100_pooled": "null",
            "latest.completion.rate_suppressed.lt_four_year_150percent": "null",
            "latest.completion.rate_suppressed.overall": 0.6646,
            "latest.completion.rate_suppressed_pell.four_year_150_pooled": 0.5965,
            "latest.completion.rate_suppressed_pell.lt_four_year_150_pooled": "null",
            "latest.cost.tuition.in_state": 11618,
            "latest.cost.tuition.out_of_state": 30592,
            "latest.earnings.10_yrs_after_entry.median": 62668,
            "latest.student.size": 64778,
            "school.city": "Tempe",
            "school.name": "Arizona State University Campus Immersion",
            "school.state": "AZ",
        },
        {
            "id": 123961,
            "latest.admissions.admission_rate.overall": 0.1202,
            "latest.completion.rate_suppressed.consumer.median_by_pred_degree": 0.5817,
            "latest.completion.rate_suppressed.consumer.overall_median": 0.5857,
            "latest.completion.rate_suppressed.four_year": 0.9226,
            "latest.completion.rate_suppressed.four_year_100_pooled": 0.7885,
            "latest.completion.rate_suppressed.four_year_200percent": 0.9208,
            "latest.completion.rate_suppressed.lt_four_year": "null",
            "latest.completion.rate_suppressed.lt_four_year_100_pooled": "null",
            "latest.completion.rate_suppressed.lt_four_year_150percent": "null",
            "latest.completion.rate_suppressed.overall": 0.9226,
            "latest.completion.rate_suppressed_pell.four_year_150_pooled": 0.9063,
            "latest.completion.rate_suppressed_pell.lt_four_year_150_pooled": "null",
            "latest.cost.tuition.in_state": 64726,
            "latest.cost.tuition.out_of_state": 64726,
            "latest.earnings.10_yrs_after_entry.median": 92498,
            "latest.student.size": 20505,
            "school.city": "Los Angeles",
            "school.name": "University of Southern California",
            "school.state": "CA",
        },
        {
            "id": 145637,
            "latest.admissions.admission_rate.overall": 0.4482,
            "latest.completion.rate_suppressed.consumer.median_by_pred_degree": 0.5817,
            "latest.completion.rate_suppressed.consumer.overall_median": 0.5857,
            "latest.completion.rate_suppressed.four_year": 0.8479,
            "latest.completion.rate_suppressed.four_year_100_pooled": 0.7172,
            "latest.completion.rate_suppressed.four_year_200percent": 0.871,
            "latest.completion.rate_suppressed.lt_four_year": "null",
            "latest.completion.rate_suppressed.lt_four_year_100_pooled": "null",
            "latest.completion.rate_suppressed.lt_four_year_150percent": "null",
            "latest.completion.rate_suppressed.overall": 0.8479,
            "latest.completion.rate_suppressed_pell.four_year_150_pooled": 0.7728,
            "latest.completion.rate_suppressed_pell.lt_four_year_150_pooled": "null",
            "latest.cost.tuition.in_state": 15714,
            "latest.cost.tuition.out_of_state": 33686,
            "latest.earnings.10_yrs_after_entry.median": 81054,
            "latest.student.size": 34031,
            "school.city": "Champaign",
            "school.name": "University of Illinois Urbana-Champaign",
            "school.state": "IL",
        },
        {
            "id": 167358,
            "latest.admissions.admission_rate.overall": 0.068,
            "latest.completion.rate_suppressed.consumer.median_by_pred_degree": 0.5817,
            "latest.completion.rate_suppressed.consumer.overall_median": 0.5857,
            "latest.completion.rate_suppressed.four_year": 0.909,
            "latest.completion.rate_suppressed.four_year_100_pooled": "null",
            "latest.completion.rate_suppressed.four_year_200percent": 0.9021,
            "latest.completion.rate_suppressed.lt_four_year": "null",
            "latest.completion.rate_suppressed.lt_four_year_100_pooled": "null",
            "latest.completion.rate_suppressed.lt_four_year_150percent": "null",
            "latest.completion.rate_suppressed.overall": 0.909,
            "latest.completion.rate_suppressed_pell.four_year_150_pooled": 0.8947,
            "latest.completion.rate_suppressed_pell.lt_four_year_150_pooled": "null",
            "latest.cost.tuition.in_state": 60192,
            "latest.cost.tuition.out_of_state": 60192,
            "latest.earnings.10_yrs_after_entry.median": 92538,
            "latest.student.size": 16172,
            "school.city": "Boston",
            "school.name": "Northeastern University",
            "school.state": "MA",
        },
        {
            "id": 170976,
            "latest.admissions.admission_rate.overall": 0.1769,
            "latest.completion.rate_suppressed.consumer.median_by_pred_degree": 0.5817,
            "latest.completion.rate_suppressed.consumer.overall_median": 0.5857,
            "latest.completion.rate_suppressed.four_year": 0.934,
            "latest.completion.rate_suppressed.four_year_100_pooled": 0.8109,
            "latest.completion.rate_suppressed.four_year_200percent": 0.9428,
            "latest.completion.rate_suppressed.lt_four_year": "null",
            "latest.completion.rate_suppressed.lt_four_year_100_pooled": "null",
            "latest.completion.rate_suppressed.lt_four_year_150percent": "null",
            "latest.completion.rate_suppressed.overall": 0.934,
            "latest.completion.rate_suppressed_pell.four_year_150_pooled": 0.8724,
            "latest.completion.rate_suppressed_pell.lt_four_year_150_pooled": "null",
            "latest.cost.tuition.in_state": 16736,
            "latest.cost.tuition.out_of_state": 55334,
            "latest.earnings.10_yrs_after_entry.median": 83648,
            "latest.student.size": 32448,
            "school.city": "Ann Arbor",
            "school.name": "University of Michigan-Ann Arbor",
            "school.state": "MI",
        },
        {
            "id": 190150,
            "latest.admissions.admission_rate.overall": 0.0395,
            "latest.completion.rate_suppressed.consumer.median_by_pred_degree": 0.5817,
            "latest.completion.rate_suppressed.consumer.overall_median": 0.5857,
            "latest.completion.rate_suppressed.four_year": 0.9528,
            "latest.completion.rate_suppressed.four_year_100_pooled": 0.8728,
            "latest.completion.rate_suppressed.four_year_200percent": 0.9584,
            "latest.completion.rate_suppressed.lt_four_year": "null",
            "latest.completion.rate_suppressed.lt_four_year_100_pooled": "null",
            "latest.completion.rate_suppressed.lt_four_year_150percent": "null",
            "latest.completion.rate_suppressed.overall": 0.9528,
            "latest.completion.rate_suppressed_pell.four_year_150_pooled": 0.9346,
            "latest.completion.rate_suppressed_pell.lt_four_year_150_pooled": "null",
            "latest.cost.tuition.in_state": 66139,
            "latest.cost.tuition.out_of_state": 66139,
            "latest.earnings.10_yrs_after_entry.median": 102491,
            "latest.student.size": 8902,
            "school.city": "New York",
            "school.name": "Columbia University in the City of New York",
            "school.state": "NY",
        },
        {
            "id": 190415,
            "latest.admissions.admission_rate.overall": 0.0747,
            "latest.completion.rate_suppressed.consumer.median_by_pred_degree": 0.5817,
            "latest.completion.rate_suppressed.consumer.overall_median": 0.5857,
            "latest.completion.rate_suppressed.four_year": 0.9473,
            "latest.completion.rate_suppressed.four_year_100_pooled": 0.8851,
            "latest.completion.rate_suppressed.four_year_200percent": 0.9574,
            "latest.completion.rate_suppressed.lt_four_year": "null",
            "latest.completion.rate_suppressed.lt_four_year_100_pooled": "null",
            "latest.completion.rate_suppressed.lt_four_year_150percent": "null",
            "latest.completion.rate_suppressed.overall": 0.9473,
            "latest.completion.rate_suppressed_pell.four_year_150_pooled": 0.9114,
            "latest.completion.rate_suppressed_pell.lt_four_year_150_pooled": "null",
            "latest.cost.tuition.in_state": 63200,
            "latest.cost.tuition.out_of_state": 63200,
            "latest.earnings.10_yrs_after_entry.median": 104043,
            "latest.student.size": 15676,
            "school.city": "Ithaca",
            "school.name": "Cornell University",
            "school.state": "NY",
        },
        {
            "id": 193900,
            "latest.admissions.admission_rate.overall": 0.1246,
            "latest.completion.rate_suppressed.consumer.median_by_pred_degree": 0.5817,
            "latest.completion.rate_suppressed.consumer.overall_median": 0.5857,
            "latest.completion.rate_suppressed.four_year": 0.87,
            "latest.completion.rate_suppressed.four_year_100_pooled": 0.7831,
            "latest.completion.rate_suppressed.four_year_200percent": 0.8756,
            "latest.completion.rate_suppressed.lt_four_year": "null",
            "latest.completion.rate_suppressed.lt_four_year_100_pooled": "null",
            "latest.completion.rate_suppressed.lt_four_year_150percent": "null",
            "latest.completion.rate_suppressed.overall": 0.87,
            "latest.completion.rate_suppressed_pell.four_year_150_pooled": 0.8575,
            "latest.completion.rate_suppressed_pell.lt_four_year_150_pooled": "null",
            "latest.cost.tuition.in_state": 58168,
            "latest.cost.tuition.out_of_state": 58168,
            "latest.earnings.10_yrs_after_entry.median": 82509,
            "latest.student.size": 29136,
            "school.city": "New York",
            "school.name": "New York University",
            "school.state": "NY",
        },
        {
            "id": 211440,
            "latest.admissions.admission_rate.overall": 0.113,
            "latest.completion.rate_suppressed.consumer.median_by_pred_degree": 0.5817,
            "latest.completion.rate_suppressed.consumer.overall_median": 0.5857,
            "latest.completion.rate_suppressed.four_year": 0.9214,
            "latest.completion.rate_suppressed.four_year_100_pooled": 0.7765,
            "latest.completion.rate_suppressed.four_year_200percent": 0.9344,
            "latest.completion.rate_suppressed.lt_four_year": "null",
            "latest.completion.rate_suppressed.lt_four_year_100_pooled": "null",
            "latest.completion.rate_suppressed.lt_four_year_150percent": "null",
            "latest.completion.rate_suppressed.overall": 0.9214,
            "latest.completion.rate_suppressed_pell.four_year_150_pooled": 0.8959,
            "latest.completion.rate_suppressed_pell.lt_four_year_150_pooled": "null",
            "latest.cost.tuition.in_state": 61344,
            "latest.cost.tuition.out_of_state": 61344,
            "latest.earnings.10_yrs_after_entry.median": 114862,
            "latest.student.size": 7005,
            "school.city": "Pittsburgh",
            "school.name": "Carnegie Mellon University",
            "school.state": "PA",
        },
        {
            "id": 228787,
            "latest.admissions.admission_rate.overall": 0.8474,
            "latest.completion.rate_suppressed.consumer.median_by_pred_degree": 0.5817,
            "latest.completion.rate_suppressed.consumer.overall_median": 0.5857,
            "latest.completion.rate_suppressed.four_year": 0.7055,
            "latest.completion.rate_suppressed.four_year_100_pooled": 0.5249,
            "latest.completion.rate_suppressed.four_year_200percent": 0.71,
            "latest.completion.rate_suppressed.lt_four_year": "null",
            "latest.completion.rate_suppressed.lt_four_year_100_pooled": "null",
            "latest.completion.rate_suppressed.lt_four_year_150percent": "null",
            "latest.completion.rate_suppressed.overall": 0.7055,
            "latest.completion.rate_suppressed_pell.four_year_150_pooled": 0.6988,
            "latest.completion.rate_suppressed_pell.lt_four_year_150_pooled": "null",
            "latest.cost.tuition.in_state": 14564,
            "latest.cost.tuition.out_of_state": 39776,
            "latest.earnings.10_yrs_after_entry.median": 68227,
            "latest.student.size": 21586,
            "school.city": "Richardson",
            "school.name": "The University of Texas at Dallas",
            "school.state": "TX",
        },
    ],
}

# %%
for uni_data in data["results"]:
    mapped_data = {
        "student_size": uni_data.get("latest.student.size"),
        "admission_rate": uni_data.get("latest.admissions.admission_rate.overall"),
        "tuition_in_state": uni_data.get("latest.cost.tuition.in_state"),
        "tuition_out_of_state": uni_data.get("latest.cost.tuition.out_of_state"),
        "earnings": uni_data.get("latest.earnings.10_yrs_after_entry.median"),
        "completion_rate_150percent": None,  # This doesn't appear to have a direct mapping
        "completion_rate_4yr": uni_data.get(
            "latest.completion.rate_suppressed.four_year"
        ),
        "completion_rate_4yr_200percent": uni_data.get(
            "latest.completion.rate_suppressed.four_year_200percent"
        ),
        "completion_rate_4yr_100_pooled": uni_data.get(
            "latest.completion.rate_suppressed.four_year_100_pooled"
        ),
        "completion_rate_consumer_median": uni_data.get(
            "latest.completion.rate_suppressed.consumer.median_by_pred_degree"
        ),
        "completion_rate_consumer_overall": uni_data.get(
            "latest.completion.rate_suppressed.consumer.overall_median"
        ),
        "completion_rate_pell_150_pooled": uni_data.get(
            "latest.completion.rate_suppressed_pell.four_year_150_pooled"
        ),
        "completion_rate_overall": uni_data.get(
            "latest.completion.rate_suppressed.overall"
        ),
        "school_name": uni_data.get("school.name"),
        "school_city": uni_data.get("school.city"),
        "school_state": uni_data.get("school.state"),
        "school_id": uni_data.get("id"),
    }
